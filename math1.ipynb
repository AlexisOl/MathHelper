# %% [markdown]
# # Prueba 1 usando numpy

# %% [markdown]
# ## Some settings
# * If you have trouble with the extension of Jupyter in vsCode,
# Go to settings and down of restart vsCode, put this command
#     - "enable-proposed-api": ["ms-toolsai.jupyter"]
#
# after that restart vscode
# If everything is fine, go ahead, and change the kernel, for the languague that you want
# * First of all, intall pip for matplotlib, if you dont have it

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,100,10)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
x = np.arange(0, 4 * np.pi, 0.1) 
y_sin = np.sin(x) 
y_cos = np.cos(x)

# %%
plt.subplot(2, 1, 1)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(2, 1, 2) 
plt.plot(x, y_cos) 
plt.title('Cos graph')
# Out:
# Text(0.5, 1.0, 'Cos graph')

# %%
plt.show()
